# %%
import numpy as np
np.random.seed()
m=100
X = 7* np.random.rand(m,1)
y = 4+np.random.rand(m,1)*X + np.random.rand(m,1)**np.random.rand(m,1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(X, y, "b.")
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
plt.axis([0, 2, 4, 10])
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import add_dummy_feature

X_b = add_dummy_feature(X)  # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y
X_new = np.array([[0], [2]])
X_new_b = add_dummy_feature(X_new)  # add x0 = 1 to each instance
y_predict = X_new_b @ theta_best
y_predict
# Out:
# array([[4.70780869],
#        [5.6868811 ]])

# %%
plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(X_new, y_predict, "r-", label="Predictions")
plt.plot(X, y, "b.")

# extra code – beautifies and saves Figure 4–2
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
plt.axis([0, 2, 4, 10])
plt.grid()
plt.legend(loc="upper left")

plt.show()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X, y)

# Make predictions using the testing set
y_pred = regr.predict(X)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y, y_pred))

# Plot outputs
plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(X, y_pred, "r-", label="Predictions")
plt.plot(X, y, "b.")

# extra code – beautifies and saves Figure 4–2
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
plt.axis([0, 2, 4, 10])
plt.grid()
plt.legend(loc="upper left")


plt.show()
# Out:
# Coefficients:
#  [[0.48953621]]
# Mean squared error: 1.18
# Coefficient of determination: 0.46

# %%
num_points = 100
x_vals = np.arange(num_points)
y_truth = np.arange(num_points)
#plt.plot(x_vals, y_truth)
rng = np.random.default_rng()
randoms = rng.integers(20, size=100)
#randoms = rng.standard_normal(100)
y_munge = y_truth * randoms
#y_truth[20:40] = x_vals[20:40] + randoms 
plt.title("Noise in y-direction")
plt.xlim([0,100])
plt.scatter(x_vals, y_munge)
